# %%
import pandas as pd
import re
import ast
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer

# Download necessary NLTK data (run once if needed)
nltk.download('punkt')        # For tokenization
nltk.download('stopwords')    # For stopwords
nltk.download('wordnet')      # For lemmatization

# Initialize necessary NLP tools
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()  # For Lemmatization
stemmer = PorterStemmer()         # For Stemming (optional)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\arthu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\arthu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\arthu\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
movies = pd.read_csv('../data/processed/merged_movies.csv')
characters = pd.read_csv('../data/MovieSummaries/character.metadata.tsv', sep = '\t', header = None)

# ignore name_clusters df
name_clusters = pd.read_csv('../data/MovieSummaries/name.clusters.txt', sep = '\t', header = None)
summaries = pd.read_csv('../data/processed/summaries_preprocessed.csv')
tv_tropes = pd.read_csv('../data/MovieSummaries/tvtropes.clusters.txt', sep = '\t', header = None)

# %%
characters.columns = ['wikipedia_movie_id', 'freebase_movie_id', 'movie_release_date', 'character_name', 'actor_birth', 'actor_gender', 'actor_height', 'actor_ethnicity', 'actor_name', 'actor_age', 'freebase_character_map', 'freebase_character_id', 'freebase_actor_id']

# %%
# removing freebase_character_ids gives approx same resulting df size
characters = characters.dropna(subset=['wikipedia_movie_id', 'character_name'])

# %% [markdown]
# Compare size of character, movie, and movie summary datasets.
# Keep only the movies which index is common between the 3 sets

# %%
print("Number of movies:", movies.shape[0])
print("Number of summaries:", summaries.shape[0])

# shows 
n_movie_in_characters = characters.drop_duplicates(subset='wikipedia_movie_id', keep='first')
print("Number of movies where we know the characters:", n_movie_in_characters.shape[0])
# Out:
# Number of movies: 8954
# Number of summaries: 42303
# Number of movies where we know the characters: 32571

# %%
common_index = movies['wikipedia_movie_id'].isin(summaries['wikipedia_movie_id']) & movies['wikipedia_movie_id'].isin(characters['wikipedia_movie_id'])
common_index2 = movies['wikipedia_movie_id'].isin(characters['wikipedia_movie_id'])
common_index3 = movies['wikipedia_movie_id'].isin(summaries['wikipedia_movie_id'])
filtered_movies_summaries_characters = movies[common_index]
filtered_movies_characters = movies[common_index2]
filtered_movies_summaries = movies[common_index3]

# %% [markdown]
# filtered_movies -> have two filtered datasets on characters and on summaries+characters since summaries currently not used?

# %%
tv_tropes.columns = ['trope', 'details']
tv_tropes['details'] = tv_tropes['details'].apply(eval)
tv_tropes = tv_tropes.join(pd.json_normalize(tv_tropes['details'])).drop(columns=['details'])

# %%
tv_tropes.columns = [
    'trope',
    'character_name',          # Change `char` to `character_name`
    'movie_name',              # Change `movie` to `movie_name`
    'freebase_movie_id',       # Change `id` to `freebase_movie_id`
    'actor_name'               # Change `actor` to `actor_name`
]

# %%
trope_counts = tv_tropes['trope'].value_counts().reset_index()
trope_counts.columns = ['trope', 'count']

# %% [markdown]
# Leave clusters with archetypes for now

# %% [markdown]
# Add tropes to character df

# %%
merged_characters = characters.merge(tv_tropes[['character_name', 'trope', 'actor_name']],
                                      on=['character_name', 'actor_name'],
                                      how='left',
                                      indicator=True)

# %% [markdown]
# Ignore part to categorize character from plot (virtually impossible)

# %%
# check uniqueness for both merges ??

# Check unique entries in filtered_movies
unique_filtered_movies = filtered_movies_summaries_characters['wikipedia_movie_id'].nunique()
total_filtered_movies = filtered_movies_summaries_characters.shape[0]

# Check unique entries in summaries
unique_summaries = summaries['wikipedia_movie_id'].nunique()
total_summaries = summaries.shape[0]

print(f"Unique entries in filtered_movies: {unique_filtered_movies}, Total entries: {total_filtered_movies}")
print(f"Unique entries in summaries: {unique_summaries}, Total entries: {total_summaries}")
# Out:
# Unique entries in filtered_movies: 6927, Total entries: 6989
# Unique entries in summaries: 42303, Total entries: 42303

# %%
filtered_movies = filtered_movies_summaries_characters.drop_duplicates()

# %%
filtered_movies
# Out:
#       wikipedia_movie_id freebase_movie_id         movie_name  \
# 0                 975900         /m/03vyhn     Ghosts of Mars
# 2                 171005         /m/016ywb            Henry V
# 3                  77856          /m/0kcn7       Mary Poppins
# 5                 156558         /m/014k4y           Baby Boy
# 8               12008535        /m/02vlsqt       Rudo y Cursi
# ...                  ...               ...                ...
# 8948             1191380         /m/04f_y7              Wilde
# 8949               54540          /m/0f7hw  Coming to America
# 8950             7761830         /m/0kvgqb    Spaced Invaders
# 8951             1918494         /m/0660qx     State and Main
# 8952              664006         /m/030xw6      Guilty as Sin
#
#       movie_release_date  movie_box_office_revenue  movie_runtime  \
# 0                 2001.0                14010832.0           98.0
# 2                 1989.0                10161099.0          137.0
# 3                 1964.0               102272727.0          139.0
# 5                 2001.0                29381649.0          123.0
# 8                 2008.0                11091868.0          103.0
# ...                  ...                       ...            ...
# 8948              1997.0                 2158775.0          118.0
# 8949              1988.0               288752301.0          117.0
# 8950              1990.0                15369573.0          100.0
# 8951              2000.0                 6944471.0          106.0
# 8952              1993.0                22886222.0          107.0
#
#                                movie_languages  \
# 0                         ['English Language']
# 2                         ['English Language']
# 3                         ['English Language']
# 5                         ['English Language']
# 8                         ['Spanish Language']
# ...                                        ...
# 8948                      ['English Language']
# 8949                      ['English Language']
# 8950                      ['English Language']
# 8951  ['Italian Language', 'English Language']
# 8952                                        []
#
#                                         movie_countries  \
# 0                          ['United States of America']
# 2                                    ['United Kingdom']
# 3                          ['United States of America']
# 5                          ['United States of America']
# 8                ['Mexico', 'United States of America']
# ...                                                 ...
# 8948  ['Kingdom of Great Britain', 'Japan', 'England...
# 8949                       ['United States of America']
# 8950                       ['United States of America']
# 8951             ['France', 'United States of America']
# 8952                       ['United States of America']
#
#                                            movie_genres
# 0     ['Thriller', 'Science Fiction', 'Horror', 'Adv...
# 2     ['Costume drama', 'War film', 'Epic', 'Period ...
# 3     ["Children's/Family", 'Musical', 'Fantasy', 'C...
# 5           ['Crime Fiction', 'Drama', 'Coming of age']
# 8     ['Sports', 'Drama', 'Family Drama', 'Comedy-dr...
# ...                                                 ...
# 8948  ['LGBT', 'Biography', 'Japanese Movies', 'Hist...
# 8949  ['Romantic comedy', 'Comedy of manners', 'Dram...
# 8950  ['Alien Film', 'Science Fiction', 'Family Film...
# 8951                  ['Parody', 'Americana', 'Comedy']
# 8952  ['Thriller', 'Erotic thriller', 'Psychological...
#
# [6927 rows x 9 columns]

# %%
characters = merged_characters

# %% [markdown]
# All entries in both DataFrames are unique. We can merge on 'wikipedia_movie_id'. Wait they are not unique

# %%
characters_with_tropes = characters[characters['trope'].notna()]

# 2. Identify movie IDs with summaries
movie_ids_with_summaries = set(summaries['wikipedia_movie_id'])

# 3. Keep characters that have either a trope or a summary
characters_with_summaries = characters[characters['wikipedia_movie_id'].isin(movie_ids_with_summaries)]

combined_characters = pd.concat([characters_with_tropes, characters_with_summaries]).drop_duplicates()
df_characters = combined_characters.drop_duplicates(subset='character_name')

print("Number of charcaters:", characters.shape[0])
print("Number of characters with either a trope or a summary:", df_characters.shape[0])
# Out:
# Number of charcaters: 192928
# Number of characters with either a trope or a summary: 96235

# %%
character_counts_per_movie = df_characters.groupby('wikipedia_movie_id').size().reset_index(name='character_count')

# Display character counts per movie
print("\nNumber of characters per movie:")
print(character_counts_per_movie)
# Out:
# Number of characters per movie:
#        wikipedia_movie_id  character_count
# 0                    3217               10
# 1                    3746               11
# 2                    3837               13
# 3                    3947                8
# 4                    4227                1
# ...                   ...              ...
# 20220            36724042                1
# 20221            36814246                5
# 20222            36956792               23
# 20223            37373877                2
# 20224            37501922                2
#
# [20225 rows x 2 columns]

# %% [markdown]
# Use imdb dataset that only has 3 main characters per movie to filter out 'unimportant' characters

# %%
imdb_movies = pd.read_csv('../data/raw/imdb_5000_movies.csv')

# %%
imdb_movies['movie_title'] = imdb_movies['movie_title'].str.strip().str.replace(u'\xa0', '')
imdb_selected = imdb_movies[['movie_title', 'title_year', 'actor_1_name', 'actor_2_name', 'actor_3_name']]

# filtered movies -> movies where there are characters as well as summary
# inner merge? -> maybe not since we are losing movies that are in original dataset but not
# in the imdb one?
# doesn't change anything keep inner merge

merged_movies = pd.merge(
    filtered_movies, imdb_selected,
    left_on=['movie_name', 'movie_release_date'],
    right_on=['movie_title', 'title_year'],
    how='inner'
)

final_characters = df_characters.merge(merged_movies[['wikipedia_movie_id', 'actor_1_name', 'actor_2_name', 'actor_3_name']],
                                        on='wikipedia_movie_id',
                                        how='inner')

# %%
final_characters = final_characters[
    (final_characters['actor_name'].isin(final_characters['actor_1_name'])) |
    (final_characters['actor_name'].isin(final_characters['actor_2_name']))
]

print(f"Number of final characters: {final_characters.shape[0]}")
# Out:
# Number of final characters: 6715

# %%
final_characters
# Out:
#        wikipedia_movie_id freebase_movie_id movie_release_date  \
# 3                22144721        /m/05qbckf         2010-04-26
# 5                  670226         /m/031gmx         2004-06-03
# 6                  999394         /m/03y0pn         2006-06-24
# 7                  999394         /m/03y0pn         2006-06-24
# 8                  999394         /m/03y0pn         2006-06-24
# ...                   ...               ...                ...
# 26834            22427855        /m/05zkcsk         2009-01-20
# 26835            22427855        /m/05zkcsk         2009-01-20
# 26838            22427855        /m/05zkcsk         2009-01-20
# 26841            25920477        /m/0b6lqyd         2011-03-11
# 26846            25920477        /m/0b6lqyd         2011-03-11
#
#              character_name actor_birth actor_gender  actor_height  \
# 3                Tony Stark  1965-04-04            M         1.750
# 5                    Toombs  1961-11-18            M         1.880
# 6            Cutler Beckett  1967-08-25            M         1.651
# 7      Captain Jack Sparrow  1963-06-09            M         1.780
# 8                Norrington  1973-03-01            M         1.854
# ...                     ...         ...          ...           ...
# 26834        Marty Buchwald  1955-08-19            M         1.750
# 26835      Rebecca Buchwald  1953-09-10            F         1.630
# 26838           Mr. Wardlow  1950-08-11            M           NaN
# 26841        Colter Stevens  1980-12-19            M         1.830
# 26846                 Hazmi         NaN            M         1.830
#
#       actor_ethnicity         actor_name  actor_age freebase_character_map  \
# 3            /m/041rx  Robert Downey Jr.       45.0             /m/0j1__j1
# 5                 NaN      Nick Chinlund       42.0              /m/0k4qdz
# 6           /m/02w7gg      Tom Hollander       38.0              /m/0k1xyw
# 7           /m/01qhm_        Johnny Depp       43.0              /m/0k1xxm
# 8                 NaN     Jack Davenport       33.0              /m/0k1xyd
# ...               ...                ...        ...                    ...
# 26834             NaN    Peter Gallagher       53.0             /m/062x1hw
# 26835        /m/041rx         Amy Irving       55.0             /m/062x1j0
# 26838             NaN       Adam LeFevre       58.0             /m/0cg4hb0
# 26841       /m/065b6q    Jake Gyllenhaal       30.0             /m/0cpl4h_
# 26846      /m/025rpb0          Cas Anvar        NaN             /m/0cs3h82
#
#       freebase_character_id freebase_actor_id                        trope
# 3                /m/0ghbqqc         /m/016z2j                 byronic_hero
# 5                /m/0h5pbks         /m/079mh2                bounty_hunter
# 6                 /m/0cwtr9         /m/0755wz  corrupt_corporate_executive
# 7                 /m/01x5g2          /m/0jfx1                 byronic_hero
# 8                /m/0cgrw9b         /m/02gqcs      officer_and_a_gentleman
# ...                     ...               ...                          ...
# 26834            /m/0glmmwb         /m/0301yj                          NaN
# 26835            /m/0glmmwk         /m/030h95                          NaN
# 26838            /m/0glmmx6         /m/07hd6p                          NaN
# 26841            /m/0ggkqv7         /m/02js6_                          NaN
# 26846            /m/0ggkqt_        /m/0bnql6d                          NaN
#
# [6715 rows x 14 columns]

# %%
# attempt with left merge
imdb_renamed = imdb_selected.rename(columns={'movie_title': 'movie_name', 'title_year': 'movie_release_date'})


merged_movies_left = filtered_movies.merge(imdb_renamed, on=['movie_name', 'movie_release_date'], how='left', indicator=True)

# %%
sorted_characters = characters.sort_values(by='wikipedia_movie_id', ascending=False)
sorted_characters
# Out:
#         wikipedia_movie_id freebase_movie_id movie_release_date  \
# 183853            37501922        /m/0c0m5vt               1992
# 183854            37501922        /m/0c0m5vt               1992
# 192341            37478048        /m/0g57c0y               1996
# 28890             37373877        /m/02vr316         2006-10-31
# 28891             37373877        /m/02vr316         2006-10-31
# ...                    ...               ...                ...
# 101746                3217          /m/014hr         1992-10-09
# 101745                3217          /m/014hr         1992-10-09
# 101744                3217          /m/014hr         1992-10-09
# 101743                3217          /m/014hr         1992-10-09
# 101739                3217          /m/014hr         1992-10-09
#
#           character_name actor_birth actor_gender  actor_height  \
# 183853       John Hunter  1966-10-11            M         1.765
# 183854      Craig Murphy  1969-07-28            F         1.720
# 192341              Ajay  1959-08-29            M         1.830
# 28890     Beth Patterson  1970-02-04            F         1.600
# 28891     Jennifer Jones  1968-12-22            F         1.700
# ...                  ...         ...          ...           ...
# 101746   Possessed Witch  1957-09-04            F         1.750
# 101745            Sheila  1965-08-11            F         1.730
# 101744             Linda  1964-01-27            F         1.680
# 101743  Cowardly Warrior  1965-12-14            M         1.870
# 101739      S-Mart Clerk  1965-12-14            M         1.870
#
#        actor_ethnicity          actor_name  actor_age freebase_character_map  \
# 183853             NaN          Luke Perry       25.0             /m/0gyqn_q
# 183854        /m/041rx     Alexis Arquette       22.0             /m/0h35_7c
# 192341       /m/09m6hr  Akkineni Nagarjuna       36.0             /m/0gw442b
# 28890       /m/03w9bjf     Gabrielle Anwar       36.0             /m/03js7xs
# 28891              NaN          Dina Meyer       37.0             /m/04db__3
# ...                ...                 ...        ...                    ...
# 101746             NaN    Patricia Tallman       35.0             /m/04hzm5r
# 101745       /m/06v41q      Embeth Davidtz       27.0              /m/0jtqtk
# 101744       /m/07hwkr       Bridget Fonda       28.0              /m/0jtqtq
# 101743             NaN           Ted Raimi       26.0             /m/04hzm5x
# 101739             NaN           Ted Raimi       26.0             /m/0hgcnkm
#
#        freebase_character_id freebase_actor_id trope     _merge
# 183853            /m/0gyqn_s         /m/01g65g   NaN  left_only
# 183854            /m/0h35_7g         /m/02zjrf   NaN  left_only
# 192341            /m/0h18dfy         /m/06pwf6   NaN  left_only
# 28890             /m/0gydnxw         /m/03s_y5   NaN  left_only
# 28891             /m/0h2m2b3         /m/02n305   NaN  left_only
# ...                      ...               ...   ...        ...
# 101746            /m/0hgcnl6         /m/045kf0   NaN  left_only
# 101745            /m/0h36j9w         /m/034b7r   NaN  left_only
# 101744            /m/0h2hxrl         /m/01yd8v   NaN  left_only
# 101743            /m/0hgcnjh          /m/07qn0   NaN  left_only
# 101739            /m/0hgcnkq          /m/07qn0   NaN  left_only
#
# [192928 rows x 15 columns]

# %%
# gets movies with only 3 characters max (assume they are the main characters)
char_count_per_movie = sorted_characters.groupby('wikipedia_movie_id')['character_name'].nunique()
movies_with_less_than_3_actors = char_count_per_movie[char_count_per_movie < 4].index

# Keep only those rows in the original DataFrame where the 'wikipedia_movie_id' is in the filtered list
characters_lessthan3_df = sorted_characters[sorted_characters['wikipedia_movie_id'].isin(movies_with_less_than_3_actors)]

characters_lessthan3_df

# NEED TO DO THE FILTERING IN 2 STEPS -> MOVIES WITH LESS thAN 3 CHARACTERS, THEN FILTER MOVIES THAT HAVE MORE THAN 3 BUT ARE IN IMDB SO WE CAN FILTER THERE
# ALSO MAKE DF SIMPLY OF ALL MOVIES WITH REVENUE AND SUMMARIES FOR ADAM'S ANALYSIS
# WHEN ADDING TO THE 2555 MOVIES, IDENTIFY THOSE NOT IN THE 2555 FOR THE NEXT WEB SCRAPE TO THEN MERGE ON ALL
# Out:
#         wikipedia_movie_id freebase_movie_id movie_release_date  \
# 183853            37501922        /m/0c0m5vt               1992
# 183854            37501922        /m/0c0m5vt               1992
# 192341            37478048        /m/0g57c0y               1996
# 28890             37373877        /m/02vr316         2006-10-31
# 28891             37373877        /m/02vr316         2006-10-31
# ...                    ...               ...                ...
# 157659                8481          /m/02c6d         1980-06-23
# 157658                8481          /m/02c6d         1980-06-23
# 134768                7906          /m/026j7               1939
# 150352                5035          /m/01l40         1956-05-11
# 16330                 4227          /m/01c9d         1975-12-18
#
#                            character_name actor_birth actor_gender  \
# 183853                        John Hunter  1966-10-11            M
# 183854                       Craig Murphy  1969-07-28            F
# 192341                               Ajay  1959-08-29            M
# 28890                      Beth Patterson  1970-02-04            F
# 28891                      Jennifer Jones  1968-12-22            F
# ...                                   ...         ...          ...
# 157659              Doctor Robert Elliott  1933-03-14            M
# 157658                        Kate Miller  1931-09-30            F
# 134768  Thomas Jefferson 'Tom' Destry Jr.  1908-05-20            M
# 150352                   Dr. Eric Vornoff  1882-10-20            M
# 16330                        Barry Lyndon  1941-04-20            M
#
#         actor_height actor_ethnicity          actor_name  actor_age  \
# 183853         1.765             NaN          Luke Perry       25.0
# 183854         1.720        /m/041rx     Alexis Arquette       22.0
# 192341         1.830       /m/09m6hr  Akkineni Nagarjuna       36.0
# 28890          1.600      /m/03w9bjf     Gabrielle Anwar       36.0
# 28891          1.700             NaN          Dina Meyer       37.0
# ...              ...             ...                 ...        ...
# 157659         1.880             NaN       Michael Caine       47.0
# 157658         1.651             NaN     Angie Dickinson       48.0
# 134768         1.910       /m/07bch9       James Stewart       30.0
# 150352         1.850       /m/08hpk0         Béla Lugosi        NaN
# 16330          1.850       /m/02ctzb         Ryan O'Neal       34.0
#
#        freebase_character_map freebase_character_id freebase_actor_id trope  \
# 183853             /m/0gyqn_q            /m/0gyqn_s         /m/01g65g   NaN
# 183854             /m/0h35_7c            /m/0h35_7g         /m/02zjrf   NaN
# 192341             /m/0gw442b            /m/0h18dfy         /m/06pwf6   NaN
# 28890              /m/03js7xs            /m/0gydnxw         /m/03s_y5   NaN
# 28891              /m/04db__3            /m/0h2m2b3         /m/02n305   NaN
# ...                       ...                   ...               ...   ...
# 157659              /m/0jxlgd            /m/0gygjrb          /m/0gnbw   NaN
# 157658              /m/0jxlgk            /m/0h13krt         /m/02lyx4   NaN
# 134768              /m/0jx6h0            /m/0gz5m4t          /m/044qx   NaN
# 150352              /m/0jvszp            /m/0h4y7bk          /m/01l3j   NaN
# 16330               /m/0jv1c2            /m/05pstf6         /m/015g_7   NaN
#
#            _merge
# 183853  left_only
# 183854  left_only
# 192341  left_only
# 28890   left_only
# 28891   left_only
# ...           ...
# 157659  left_only
# 157658  left_only
# 134768  left_only
# 150352  left_only
# 16330   left_only
#
# [28640 rows x 15 columns]

# %%
# Take movies with less than x characters and make it one row per movie with the x character names and actor names as columns
import numpy as np

# Assuming you have your original DataFrame named df
# Group the data by wikipedia_movie_id and collect actor names
grouped = characters_lessthan3_df.groupby('wikipedia_movie_id').agg({
    'actor_name': lambda x: list(x),  # Collect actor names as a list
    'character_name': lambda x: list(x)  # Collect character names as a list
}).reset_index()


def extract_info(info_list):
    # If there are fewer than 3 items, pad with NaN
    info_list += [np.nan] * (3 - len(info_list))
    return info_list[:3]

# Apply the function to create separate actor and character columns
grouped[['actor1_name', 'actor2_name', 'actor3_name']] = pd.DataFrame(
    grouped['actor_name'].apply(extract_info).to_list(),
    index=grouped.index
)

grouped[['character1_name', 'character2_name', 'character3_name']] = pd.DataFrame(
    grouped['character_name'].apply(extract_info).to_list(),
    index=grouped.index
)

# Drop the original actor_name and character_name columns
grouped = grouped.drop(columns=['actor_name', 'character_name'])

# Merge the new columns back to the original DataFrame
result = characters_lessthan3_df.drop_duplicates('wikipedia_movie_id').merge(
    grouped, on='wikipedia_movie_id', how='left'
)

# Keep only the relevant columns
columns_to_keep = ['wikipedia_movie_id', 'freebase_movie_id', 'movie_release_date', 
                   'actor1_name', 'actor2_name', 'actor3_name',
                   'character1_name', 'character2_name', 'character3_name']
result = result[columns_to_keep]

result.head()
# Out:
#    wikipedia_movie_id freebase_movie_id movie_release_date  \
# 0            37501922        /m/0c0m5vt               1992
# 1            37478048        /m/0g57c0y               1996
# 2            37373877        /m/02vr316         2006-10-31
# 3            37322106        /m/0hzp_vq         2012-11-13
# 4            37090987        /m/080j6zc         1949-11-25
#
#           actor1_name      actor2_name actor3_name character1_name  \
# 0          Luke Perry  Alexis Arquette         NaN     John Hunter
# 1  Akkineni Nagarjuna              NaN         NaN            Ajay
# 2     Gabrielle Anwar       Dina Meyer         NaN  Beth Patterson
# 3       Shahrukh Khan              NaN         NaN     Major Samar
# 4      Shirley Temple              NaN         NaN  Corliss Archer
#
#   character2_name character3_name
# 0    Craig Murphy             NaN
# 1             NaN             NaN
# 2  Jennifer Jones             NaN
# 3             NaN             NaN
# 4             NaN             NaN

# %%
with_BO = characters_lessthan3_df.merge(movies, on='wikipedia_movie_id', how='inner')
with_BO.columns
# Out:
# Index(['wikipedia_movie_id', 'freebase_movie_id_x', 'movie_release_date_x',
#        'character_name', 'actor_birth', 'actor_gender', 'actor_height',
#        'actor_ethnicity', 'actor_name', 'actor_age', 'freebase_character_map',
#        'freebase_character_id', 'freebase_actor_id', 'trope', '_merge',
#        'freebase_movie_id_y', 'movie_name', 'movie_release_date_y',
#        'movie_box_office_revenue', 'movie_runtime', 'movie_languages',
#        'movie_countries', 'movie_genres'],
#       dtype='object')

# %%
# Take movies with less than x characters and make it one row per movie with the x character names and actor names as columns
import numpy as np

# Assuming you have your original DataFrame named df
# Group the data by wikipedia_movie_id and collect actor names
groupedd = with_BO.groupby('wikipedia_movie_id').agg({
    'actor_name': lambda x: list(x),  # Collect actor names as a list
    'character_name': lambda x: list(x)  # Collect character names as a list
}).reset_index()


def extract_info(info_list):
    # If there are fewer than 3 items, pad with NaN
    info_list += [np.nan] * (3 - len(info_list))
    return info_list[:3]

# Apply the function to create separate actor and character columns
groupedd[['actor1_name', 'actor2_name', 'actor3_name']] = pd.DataFrame(
    groupedd['actor_name'].apply(extract_info).to_list(),
    index=groupedd.index
)

groupedd[['character1_name', 'character2_name', 'character3_name']] = pd.DataFrame(
    groupedd['character_name'].apply(extract_info).to_list(),
    index=groupedd.index
)

# Drop the original actor_name and character_name columns
groupedd = groupedd.drop(columns=['actor_name', 'character_name'])

# Merge the new columns back to the original DataFrame
resultt = with_BO.drop_duplicates('wikipedia_movie_id').merge(
    groupedd, on='wikipedia_movie_id', how='left'
)

# Keep only the relevant columns
columns_to_keep = ['wikipedia_movie_id', 'freebase_movie_id_x', 'movie_release_date_x', 
                   'actor1_name', 'actor2_name', 'actor3_name',
                   'character1_name', 'character2_name', 'character3_name', 'movie_box_office_revenue']
resultt = resultt[columns_to_keep]

resultt.sample(10)
# Out:
#       wikipedia_movie_id freebase_movie_id_x movie_release_date_x  \
# 928              6406105           /m/0g44ng           1991-02-01
# 1104             4944673           /m/0cwfgz           1989-08-04
# 1061             5257744           /m/0db6mh           1982-04-02
# 1312             3497579           /m/09gr4b           1949-05-04
# 1563             2382573           /m/0780z8              1998-01
# 1721             1840870           /m/0603hj           1993-07-30
# 72              30470501          /m/0fpvxnz                 2010
# 285             21586321          /m/05myy97           1994-09-09
# 525             12985644          /m/02z28m8           2007-10-05
# 2110              657824           /m/030bg4           1994-07-29
#
#         actor1_name         actor2_name    actor3_name        character1_name  \
# 928   Kelly Preston     Patrick Dempsey            NaN          Karen Landers
# 1104   Tom Sizemore  Sylvester Stallone    Danny Trejo                 Dallas
# 1061  Richard Pryor       Margot Kidder  Richard Pryor      Cpl. Eddie Keller
# 1312   Fred Astaire       Ginger Rogers            NaN           Josh Barkley
# 1563  Holly Madison                 NaN            NaN  Miss Lady Bright Eyes
# 1721  Wesley Snipes         Tia Carrere   Sean Connery      Lt. Webster Smith
# 72    Maki Horikita                 NaN            NaN        Yukiho Karasawa
# 285   Gabriel Byrne      Joanne Whalley   William Hurt          Daniel Graham
# 525   Kellita Smith                 NaN            NaN                  Tanya
# 2110  Thomas Gibson        Mira Sorvino            NaN          Dickie Taylor
#
#      character2_name      character3_name  movie_box_office_revenue
# 928   Charlie Farrow                  NaN                 4409328.0
# 1104     Frank Leone  Chink's Gang Member                22099847.0
# 1061    Toni Donovan            Ted Segal                23671186.0
# 1312   Dinah Barkley                  NaN                 3200000.0
# 1563             NaN                  NaN                 4000000.0
# 1721   Jingo Asakuma    Capt. John Connor               107198790.0
# 72               NaN                  NaN                 4593914.0
# 285   Valerie Alston          Tommy Vesey                 6971777.0
# 525              NaN                  NaN                 6451106.0
# 2110    Marta Ferrer                  NaN                 7266973.0

# %%
resultt.shape
# Out:
# (2385, 10)

# %%
columns_to_drop = ['_merge', 'actor_1_name', 'actor_2_name', 'actor_3_name']
final_characters = final_characters.drop(columns=columns_to_drop)

# %%
valid_wikipedia_ids = final_characters['wikipedia_movie_id'].unique()
filtered_merged_movies = merged_movies[merged_movies['wikipedia_movie_id'].isin(valid_wikipedia_ids)]

# %%
unique_ids_counss = filtered_merged_movies['wikipedia_movie_id'].nunique()
unique_ids_counss
# Out:
# 2496

# %%
web_scrape_sample_1 = filtered_merged_movies['wikipedia_movie_id']

# %%
web_scrape_sample_1.to_csv('../data/processed/web_scrape_sample_1.csv')

# %%
half1 = web_scrape_sample_1.iloc[:len(web_scrape_sample_1)//2]
half2 = web_scrape_sample_1.iloc[len(web_scrape_sample_1)//2:]


half1.to_csv('../data/processed/web_scrape_sample_half_1.csv')
half2.to_csv('../data/processed/web_scrape_sample_half_2.csv')

# %%
# I have resultt and filtered_merged_movies

combined__ = resultt.merge(filtered_merged_movies, on='wikipedia_movie_id', how='outer', indicator=True)

# %%
combined__[combined__['_merge'] == 'both']
# Out:
#       wikipedia_movie_id freebase_movie_id_x movie_release_date_x  \
# 3                   4227            /m/01c9d           1975-12-18
# 9                   8481            /m/02c6d           1980-06-23
# 52                 42159            /m/0bl5c                 1946
# 72                 45568            /m/0ccsq           1989-08-09
# 87                 60155            /m/0gclv                 1933
# ...                  ...                 ...                  ...
# 4651            31267756          /m/0gjc1d3                 2012
# 4656            31363435          /m/0g6tx_3                 2010
# 4715            33157118          /m/0h7lg4p           2004-10-14
# 4752            34643655          /m/0gkyxjc           2013-07-18
# 4760            35460624          /m/0gy75pd           2013-09-20
#
#           actor1_name        actor2_name                  actor3_name  \
# 3         Ryan O'Neal                NaN                          NaN
# 9       Michael Caine    Angie Dickinson                          NaN
# 52      Fredric March          Myrna Loy                          NaN
# 72      Michael Biehn          Ed Harris  Mary Elizabeth Mastrantonio
# 87           Mae West         Cary Grant                          NaN
# ...               ...                ...                          ...
# 4651       Josh Lucas       Nicolas Cage                          NaN
# 4656  Jacques Gamblin     Sara Forestier                          NaN
# 4715      Adam Garcia  Jacqueline Bisset                          NaN
# 4752    Ryan Reynolds                NaN                          NaN
# 4760  Chris Hemsworth       Daniel Brühl                          NaN
#
#             character1_name       character2_name  character3_name  \
# 3              Barry Lyndon                   NaN              NaN
# 9     Doctor Robert Elliott           Kate Miller              NaN
# 52            Al Stephenson      Milly Stephenson              NaN
# 72         Lt. Hiram Coffey  Virgil 'Bud' Brigman  Lindsey Brigman
# 87                 Lady Lou      Captain Cummings              NaN
# ...                     ...                   ...              ...
# 4651             Cab Driver       Will Montgomery              NaN
# 4656          Arthur Martin      Bahia Benmahmoud              NaN
# 4715          Scott Doherty       Maureen Doherty              NaN
# 4752                  Turbo                   NaN              NaN
# 4760             James Hunt            Niki Lauda              NaN
#
#       movie_box_office_revenue_x  ... movie_runtime  \
# 3                     20000000.0  ...         187.0
# 9                     31899000.0  ...         105.0
# 52                    23650000.0  ...         168.0
# 72                    90000098.0  ...         145.0
# 87                     2200000.0  ...          66.0
# ...                          ...  ...           ...
# 4651                   2106557.0  ...          96.0
# 4656                    513836.0  ...         102.0
# 4715                     16066.0  ...          95.0
# 4752                  83024900.0  ...          93.0
# 4760                  26903709.0  ...          93.0
#
#                                         movie_languages  \
# 3     ['French Language', 'English Language', 'Germa...
# 9                                  ['English Language']
# 52                                 ['English Language']
# 72                                 ['English Language']
# 87                                 ['English Language']
# ...                                                 ...
# 4651                               ['English Language']
# 4656                                ['French Language']
# 4715                               ['English Language']
# 4752                               ['English Language']
# 4760                               ['English Language']
#
#                                      movie_countries  \
# 3     ['United States of America', 'United Kingdom']
# 9                       ['United States of America']
# 52                      ['United States of America']
# 72                      ['United States of America']
# 87                      ['United States of America']
# ...                                              ...
# 4651                    ['United States of America']
# 4656                                      ['France']
# 4715                   ['United Kingdom', 'Germany']
# 4752                    ['United States of America']
# 4760                    ['United States of America']
#
#                                            movie_genres  \
# 3     ['Costume drama', 'Film adaptation', 'Period p...
# 9     ['Thriller', 'Horror', 'Erotica', 'Mystery', '...
# 52    ['Ensemble Film', 'Family Drama', 'Americana',...
# 72             ['Thriller', 'Science Fiction', 'Drama']
# 87    ['Romantic comedy', 'Crime Comedy', 'Screwball...
# ...                                                 ...
# 4651                                         ['Action']
# 4656  ['Romantic comedy', 'World cinema', 'Drama', '...
# 4715  ['Thriller', 'Erotic thriller', 'Psychological...
# 4752                ['Computer Animation', 'Animation']
# 4760  ['Sports', 'Biographical film', 'Action', 'Dra...
#
#                       movie_title title_year     actor_1_name  \
# 3                    Barry Lyndon     1975.0      Ryan O'Neal
# 9                 Dressed to Kill     1980.0  Angie Dickinson
# 52    The Best Years of Our Lives     1946.0        Myrna Loy
# 72                      The Abyss     1989.0    Michael Biehn
# 87             She Done Him Wrong     1933.0         Mae West
# ...                           ...        ...              ...
# 4651                       Stolen     2012.0     Nicolas Cage
# 4656            The Names of Love     2010.0   Sara Forestier
# 4715                  Fascination     2004.0      Adam Garcia
# 4752                        Turbo     2013.0    Ryan Reynolds
# 4760                         Rush     2013.0  Chris Hemsworth
#
#            actor_2_name                 actor_3_name  _merge
# 3        Steven Berkoff                 Hardy Krüger    both
# 9       David Margulies                  Nancy Allen    both
# 52        Teresa Wright                 Dana Andrews    both
# 72           Todd Graff  Mary Elizabeth Mastrantonio    both
# 87       Gilbert Roland               Louise Beavers    both
# ...                 ...                          ...     ...
# 4651        Mark Valley                   Sami Gayle    both
# 4656    Jacques Gamblin             Zinedine Soualem    both
# 4715  Jacqueline Bisset                  Alice Evans    both
# 4752         Snoop Dogg                 Ben Schwartz    both
# 4760       Olivia Wilde         Alexandra Maria Lara    both
#
# [153 rows x 24 columns]

# %%
combined__[combined__['_merge'] == 'left_only']
# Out:
#       wikipedia_movie_id freebase_movie_id_x movie_release_date_x  \
# 44                 31908            /m/07vcx           1991-12-25
# 50                 41881            /m/0bj25                 1950
# 63                 43849            /m/0b_5d           1960-06-15
# 65                 44218            /m/0c1p3           1936-06-26
# 70                 44752            /m/0c5wn           1932-04-12
# ...                  ...                 ...                  ...
# 4782            36353137          /m/0k3m48j                 2013
# 4783            36353520          /m/0fprltf           1953-01-31
# 4784            36353890          /m/09rr39n           1953-01-14
# 4785            36354224          /m/09rz62m           1953-06-19
# 4788            37322106          /m/0hzp_vq           2012-11-13
#
#            actor1_name     actor2_name  actor3_name         character1_name  \
# 44           Sam Neill    William Hurt          NaN      Eugene Fitzpatrick
# 50      Marilyn Monroe     Anne Baxter  Bette Davis            Miss Caswell
# 63    Shirley MacLaine     Jack Lemmon          NaN            Fran Kubelik
# 65         Clark Gable   Spencer Tracy          NaN          Blackie Norton
# 70       Joan Crawford  John Barrymore  Greta Garbo              Flaemmchen
# ...                ...             ...          ...                     ...
# 4782     Lindsay Lohan             NaN          NaN                    Tara
# 4783    Randolph Scott             NaN          NaN  Major Ransome Callicut
# 4784      Julie Newmar             NaN          NaN        Specialty Dancer
# 4785      Anita Ekberg     Fess Parker          NaN          Dancehall Girl
# 4788     Shahrukh Khan             NaN          NaN             Major Samar
#
#               character2_name         character3_name  \
# 44                 Sam Farber                     NaN
# 50             Eve Harrington          Margo Channing
# 63          C.C. 'Bud' Baxter                     NaN
# 65              Father Mullin                     NaN
# 70    Baron Felix Von Gaigern  Elizaveta Grushinskaya
# ...                       ...                     ...
# 4782                      NaN                     NaN
# 4783                      NaN                     NaN
# 4784                      NaN                     NaN
# 4785                Long John                     NaN
# 4788                      NaN                     NaN
#
#       movie_box_office_revenue_x  ... movie_runtime movie_languages  \
# 44                      752856.0  ...           NaN             NaN
# 50                     2900000.0  ...           NaN             NaN
# 63                    24600000.0  ...           NaN             NaN
# 65                     2868000.0  ...           NaN             NaN
# 70                     2250000.0  ...           NaN             NaN
# ...                          ...  ...           ...             ...
# 4782                     49494.0  ...           NaN             NaN
# 4783                   2000000.0  ...           NaN             NaN
# 4784                   1250000.0  ...           NaN             NaN
# 4785                   1000000.0  ...           NaN             NaN
# 4788                   3047539.0  ...           NaN             NaN
#
#       movie_countries  movie_genres  movie_title title_year actor_1_name  \
# 44                NaN           NaN          NaN        NaN          NaN
# 50                NaN           NaN          NaN        NaN          NaN
# 63                NaN           NaN          NaN        NaN          NaN
# 65                NaN           NaN          NaN        NaN          NaN
# 70                NaN           NaN          NaN        NaN          NaN
# ...               ...           ...          ...        ...          ...
# 4782              NaN           NaN          NaN        NaN          NaN
# 4783              NaN           NaN          NaN        NaN          NaN
# 4784              NaN           NaN          NaN        NaN          NaN
# 4785              NaN           NaN          NaN        NaN          NaN
# 4788              NaN           NaN          NaN        NaN          NaN
#
#      actor_2_name actor_3_name     _merge
# 44            NaN          NaN  left_only
# 50            NaN          NaN  left_only
# 63            NaN          NaN  left_only
# 65            NaN          NaN  left_only
# 70            NaN          NaN  left_only
# ...           ...          ...        ...
# 4782          NaN          NaN  left_only
# 4783          NaN          NaN  left_only
# 4784          NaN          NaN  left_only
# 4785          NaN          NaN  left_only
# 4788          NaN          NaN  left_only
#
# [2234 rows x 24 columns]

# %%
combined__[combined__['_merge'] == 'right_only']
# Out:
#       wikipedia_movie_id freebase_movie_id_x movie_release_date_x actor1_name  \
# 0                   3217                 NaN                  NaN         NaN
# 1                   3746                 NaN                  NaN         NaN
# 2                   3837                 NaN                  NaN         NaN
# 4                   4560                 NaN                  NaN         NaN
# 5                   4726                 NaN                  NaN         NaN
# ...                  ...                 ...                  ...         ...
# 4766            35729649                 NaN                  NaN         NaN
# 4773            35874076                 NaN                  NaN         NaN
# 4776            36019569                 NaN                  NaN         NaN
# 4786            36534974                 NaN                  NaN         NaN
# 4787            36814246                 NaN                  NaN         NaN
#
#      actor2_name actor3_name character1_name character2_name character3_name  \
# 0            NaN         NaN             NaN             NaN             NaN
# 1            NaN         NaN             NaN             NaN             NaN
# 2            NaN         NaN             NaN             NaN             NaN
# 4            NaN         NaN             NaN             NaN             NaN
# 5            NaN         NaN             NaN             NaN             NaN
# ...          ...         ...             ...             ...             ...
# 4766         NaN         NaN             NaN             NaN             NaN
# 4773         NaN         NaN             NaN             NaN             NaN
# 4776         NaN         NaN             NaN             NaN             NaN
# 4786         NaN         NaN             NaN             NaN             NaN
# 4787         NaN         NaN             NaN             NaN             NaN
#
#       movie_box_office_revenue_x  ... movie_runtime  \
# 0                            NaN  ...          81.0
# 1                            NaN  ...         116.0
# 2                            NaN  ...          93.0
# 4                            NaN  ...         175.0
# 5                            NaN  ...         126.0
# ...                          ...  ...           ...
# 4766                         NaN  ...          93.0
# 4773                         NaN  ...          93.0
# 4776                         NaN  ...         127.0
# 4786                         NaN  ...          93.0
# 4787                         NaN  ...         109.0
#
#                                         movie_languages  \
# 0                                  ['English Language']
# 1     ['Japanese Language', 'Cantonese', 'English La...
# 2              ['Yiddish Language', 'English Language']
# 4     ['French Language', 'Latin Language', 'English...
# 5               ['French Language', 'English Language']
# ...                                                 ...
# 4766                                                 []
# 4773                               ['English Language']
# 4776                               ['English Language']
# 4786                               ['English Language']
# 4787                               ['English Language']
#
#                                      movie_countries  \
# 0                       ['United States of America']
# 1          ['United States of America', 'Hong Kong']
# 2                       ['United States of America']
# 4                       ['United States of America']
# 5     ['United States of America', 'United Kingdom']
# ...                                              ...
# 4766                    ['United States of America']
# 4773                                      ['France']
# 4776                    ['United States of America']
# 4786                    ['United States of America']
# 4787                    ['United States of America']
#
#                                            movie_genres  \
# 0     ['Cult', 'Horror', 'Stop motion', 'Costume dra...
# 1     ['Thriller', 'Cyberpunk', 'Science Fiction', '...
# 2                       ['Western', 'Satire', 'Comedy']
# 4     ['Biography', 'Adventure', 'History', 'War fil...
# 5     ['Crime Fiction', 'Thriller', 'Superhero movie...
# ...                                                 ...
# 4766  ['Thriller', 'Mystery', 'Crime Fiction', 'Drama']
# 4773   ['Thriller', 'Crime Fiction', 'Action', 'Drama']
# 4776        ['Drama', 'Action', 'Fantasy', 'Adventure']
# 4786                               ['Drama', 'Fantasy']
# 4787  ['Science Fiction', 'Horror', 'Indie', 'Experi...
#
#                       movie_title title_year      actor_1_name  \
# 0                Army of Darkness     1992.0  Patricia Tallman
# 1                    Blade Runner     1982.0     Harrison Ford
# 2                 Blazing Saddles     1974.0     Madeline Kahn
# 4                      Braveheart     1995.0     Mhairi Calvey
# 5                          Batman     1989.0     Michael Gough
# ...                           ...        ...               ...
# 4766                 End of Watch     2012.0   Jake Gyllenhaal
# 4773                      Taken 2     2012.0       Liam Neeson
# 4776  Snow White and the Huntsman     2012.0   Chris Hemsworth
# 4786                         Noah     2014.0   Anthony Hopkins
# 4787                   Eraserhead     1977.0    Hal Landon Jr.
#
#           actor_2_name       actor_3_name      _merge
# 0        Bridget Fonda     Embeth Davidtz  right_only
# 1           Sean Young     M. Emmet Walsh  right_only
# 2     David Huddleston      Harvey Korman  right_only
# 4     Patrick McGoohan     James Robinson  right_only
# 5         Jack Palance   William Hootkins  right_only
# ...                ...                ...         ...
# 4766     Anna Kendrick    America Ferrera  right_only
# 4773       Luke Grimes       D.B. Sweeney  right_only
# 4776   Kristen Stewart        Sam Claflin  right_only
# 4786       Emma Watson       Logan Lerman  right_only
# 4787        Jack Nance  Charlotte Stewart  right_only
#
# [2402 rows x 24 columns]

# %%
unique_ids_countsss = combined__['wikipedia_movie_id'].nunique()
unique_ids_countsss
# Out:
# 4730

# %%
id_counts = combined__['wikipedia_movie_id'].value_counts()

# Filter for ids that appear only once
unique_ids = id_counts[id_counts == 1].index

# Filter the DataFrame to show only rows with these unique ids
unique_rows = combined__[~combined__['wikipedia_movie_id'].isin(unique_ids)]

unique_rows
# Out:
#       wikipedia_movie_id freebase_movie_id_x movie_release_date_x actor1_name  \
# 32                 30275                 NaN                  NaN         NaN
# 33                 30275                 NaN                  NaN         NaN
# 144                75933                 NaN                  NaN         NaN
# 145                75933                 NaN                  NaN         NaN
# 182                91133                 NaN                  NaN         NaN
# ...                  ...                 ...                  ...         ...
# 4563            28882162                 NaN                  NaN         NaN
# 4635            30951080                 NaN                  NaN         NaN
# 4636            30951080                 NaN                  NaN         NaN
# 4720            33279717                 NaN                  NaN         NaN
# 4721            33279717                 NaN                  NaN         NaN
#
#      actor2_name actor3_name character1_name character2_name character3_name  \
# 32           NaN         NaN             NaN             NaN             NaN
# 33           NaN         NaN             NaN             NaN             NaN
# 144          NaN         NaN             NaN             NaN             NaN
# 145          NaN         NaN             NaN             NaN             NaN
# 182          NaN         NaN             NaN             NaN             NaN
# ...          ...         ...             ...             ...             ...
# 4563         NaN         NaN             NaN             NaN             NaN
# 4635         NaN         NaN             NaN             NaN             NaN
# 4636         NaN         NaN             NaN             NaN             NaN
# 4720         NaN         NaN             NaN             NaN             NaN
# 4721         NaN         NaN             NaN             NaN             NaN
#
#       movie_box_office_revenue_x  ... movie_runtime  \
# 32                           NaN  ...          96.0
# 33                           NaN  ...          96.0
# 144                          NaN  ...         119.0
# 145                          NaN  ...         119.0
# 182                          NaN  ...         127.0
# ...                          ...  ...           ...
# 4563                         NaN  ...          95.0
# 4635                         NaN  ...          93.0
# 4636                         NaN  ...          93.0
# 4720                         NaN  ...         102.0
# 4721                         NaN  ...         102.0
#
#                                 movie_languages  \
# 32                         ['English Language']
# 33                         ['English Language']
# 144                        ['English Language']
# 145                        ['English Language']
# 182   ['Japanese Language', 'English Language']
# ...                                         ...
# 4563                       ['English Language']
# 4635                                         []
# 4636                                         []
# 4720                       ['English Language']
# 4721                       ['English Language']
#
#                                         movie_countries  \
# 32                         ['United States of America']
# 33                         ['United States of America']
# 144      ['United States of America', 'United Kingdom']
# 145      ['United States of America', 'United Kingdom']
# 182               ['United States of America', 'Japan']
# ...                                                 ...
# 4563  ['United States of America', 'India', 'United ...
# 4635                                                 []
# 4636                                                 []
# 4720                       ['United States of America']
# 4721                       ['United States of America']
#
#                                            movie_genres  \
# 32    ['Horror', 'Indie', 'Doomsday film', 'Black-an...
# 33    ['Horror', 'Indie', 'Doomsday film', 'Black-an...
# 144   ['Costume drama', 'Period piece', 'Drama', 'Co...
# 145   ['Costume drama', 'Period piece', 'Drama', 'Co...
# 182   ['Action/Adventure', 'Japanese Movies', 'Adven...
# ...                                                 ...
# 4563          ['Thriller', 'Science Fiction', 'Action']
# 4635                          ['Romance Film', 'Drama']
# 4636                          ['Romance Film', 'Drama']
# 4720                      ['Science Fiction', 'Comedy']
# 4721                      ['Science Fiction', 'Comedy']
#
#                    movie_title title_year       actor_1_name  \
# 32    Night of the Living Dead     1968.0       Judith O'Dea
# 33    Night of the Living Dead     1968.0       Judith O'Dea
# 144         Dangerous Liaisons     1988.0       Keanu Reeves
# 145         Dangerous Liaisons     1988.0       Keanu Reeves
# 182             The Karate Kid     1984.0        Martin Kove
# ...                        ...        ...                ...
# 4563                     Dredd     2012.0        Wood Harris
# 4635          The Great Gatsby     2013.0  Leonardo DiCaprio
# 4636          The Great Gatsby     2013.0  Leonardo DiCaprio
# 4720                 The Watch     2012.0         Will Forte
# 4721                 The Watch     2012.0         Will Forte
#
#            actor_2_name        actor_3_name      _merge
# 32          Duane Jones  S. William Hinzman  right_only
# 33          Duane Jones  S. William Hinzman  right_only
# 144       Peter Capaldi       Swoosie Kurtz  right_only
# 145       Peter Capaldi       Swoosie Kurtz  right_only
# 182       William Zabka     William Bassett  right_only
# ...                 ...                 ...         ...
# 4563         Jason Cope         Rakie Ayola  right_only
# 4635  Elizabeth Debicki        Steve Bisley  right_only
# 4636  Elizabeth Debicki        Steve Bisley  right_only
# 4720     Nicholas Braun    Rosemarie DeWitt  right_only
# 4721     Nicholas Braun    Rosemarie DeWitt  right_only
#
# [116 rows x 24 columns]

# %%
resultt = resultt.drop_duplicates(subset='wikipedia_movie_id', keep='first')
filtered_merged_movies = filtered_merged_movies.drop_duplicates(subset='wikipedia_movie_id', keep='first')
combined__ = combined__.drop_duplicates(subset='wikipedia_movie_id', keep='first')

# %%
resultt
# Out:
#       wikipedia_movie_id freebase_movie_id_x movie_release_date_x  \
# 0               37322106          /m/0hzp_vq           2012-11-13
# 1               36354224          /m/09rz62m           1953-06-19
# 2               36353890          /m/09rr39n           1953-01-14
# 3               36353520          /m/0fprltf           1953-01-31
# 4               36353137          /m/0k3m48j                 2013
# ...                  ...                 ...                  ...
# 2380               42159            /m/0bl5c                 1946
# 2381               41881            /m/0bj25                 1950
# 2382               31908            /m/07vcx           1991-12-25
# 2383                8481            /m/02c6d           1980-06-23
# 2384                4227            /m/01c9d           1975-12-18
#
#          actor1_name      actor2_name  actor3_name         character1_name  \
# 0      Shahrukh Khan              NaN          NaN             Major Samar
# 1       Anita Ekberg      Fess Parker          NaN          Dancehall Girl
# 2       Julie Newmar              NaN          NaN        Specialty Dancer
# 3     Randolph Scott              NaN          NaN  Major Ransome Callicut
# 4      Lindsay Lohan              NaN          NaN                    Tara
# ...              ...              ...          ...                     ...
# 2380   Fredric March        Myrna Loy          NaN           Al Stephenson
# 2381  Marilyn Monroe      Anne Baxter  Bette Davis            Miss Caswell
# 2382       Sam Neill     William Hurt          NaN      Eugene Fitzpatrick
# 2383   Michael Caine  Angie Dickinson          NaN   Doctor Robert Elliott
# 2384     Ryan O'Neal              NaN          NaN            Barry Lyndon
#
#        character2_name character3_name  movie_box_office_revenue
# 0                  NaN             NaN                 3047539.0
# 1            Long John             NaN                 1000000.0
# 2                  NaN             NaN                 1250000.0
# 3                  NaN             NaN                 2000000.0
# 4                  NaN             NaN                   49494.0
# ...                ...             ...                       ...
# 2380  Milly Stephenson             NaN                23650000.0
# 2381    Eve Harrington  Margo Channing                 2900000.0
# 2382        Sam Farber             NaN                  752856.0
# 2383       Kate Miller             NaN                31899000.0
# 2384               NaN             NaN                20000000.0
#
# [2385 rows x 10 columns]

# %%
filtered_merged_movies
# Out:
#       wikipedia_movie_id freebase_movie_id      movie_name  \
# 0                 975900         /m/03vyhn  Ghosts of Mars
# 1                 171005         /m/016ywb         Henry V
# 2                  77856          /m/0kcn7    Mary Poppins
# 3                 156558         /m/014k4y        Baby Boy
# 5                1305819         /m/04rjwf        C.H.U.D.
# ...                  ...               ...             ...
# 3063            10149834        /m/02q3fdr           Ponyo
# 3064             2472440         /m/07gf00      Turbulence
# 3065            22427855        /m/05zkcsk            Adam
# 3066              303933         /m/01s7w3         Twister
# 3067            25920477        /m/0b6lqyd     Source Code
#
#       movie_release_date  movie_box_office_revenue  movie_runtime  \
# 0                 2001.0                14010832.0           98.0
# 1                 1989.0                10161099.0          137.0
# 2                 1964.0               102272727.0          139.0
# 3                 2001.0                29381649.0          123.0
# 5                 1984.0                 4650000.0           96.0
# ...                  ...                       ...            ...
# 3063              2008.0               202614288.0          101.0
# 3064              1997.0                11538235.0          101.0
# 3065              2009.0                 2549605.0           99.0
# 3066              1996.0               494471524.0          113.0
# 3067              2011.0               147332697.0           93.0
#
#             movie_languages                         movie_countries  \
# 0      ['English Language']            ['United States of America']
# 1      ['English Language']                      ['United Kingdom']
# 2      ['English Language']            ['United States of America']
# 3      ['English Language']            ['United States of America']
# 5      ['English Language']            ['United States of America']
# ...                     ...                                     ...
# 3063  ['Japanese Language']                               ['Japan']
# 3064   ['English Language']            ['United States of America']
# 3065   ['English Language']            ['United States of America']
# 3066   ['English Language']            ['United States of America']
# 3067   ['English Language']  ['France', 'United States of America']
#
#                                            movie_genres     movie_title  \
# 0     ['Thriller', 'Science Fiction', 'Horror', 'Adv...  Ghosts of Mars
# 1     ['Costume drama', 'War film', 'Epic', 'Period ...         Henry V
# 2     ["Children's/Family", 'Musical', 'Fantasy', 'C...    Mary Poppins
# 3           ['Crime Fiction', 'Drama', 'Coming of age']        Baby Boy
# 5     ['Monster movie', 'Natural horror films', 'Sci...        C.H.U.D.
# ...                                                 ...             ...
# 3063  ['Japanese Movies', 'Adventure', 'World cinema...           Ponyo
# 3064  ['Thriller', 'Disaster', 'Action', 'Action/Adv...      Turbulence
# 3065  ['Indie', 'Comedy-drama', 'Drama', 'Comedy', '...            Adam
# 3066                   ['Action/Adventure', 'Disaster']         Twister
# 3067  ['Thriller', 'Science Fiction', 'Action/Advent...     Source Code
#
#       title_year            actor_1_name   actor_2_name        actor_3_name
# 0         2001.0           Jason Statham    Clea DuVall  Natasha Henstridge
# 1         1989.0           Brian Blessed   Derek Jacobi          Danny Webb
# 2         1964.0                 Ed Wynn   Glynis Johns     Elsa Lanchester
# 3         2001.0                Mo'Nique     Snoop Dogg      Angell Conwell
# 5         1984.0            Daniel Stern     John Heard        Sam McMurray
# ...          ...                     ...            ...                 ...
# 3063      2008.0            Rumi Hiiragi     Yûki Amami          Yuria Nara
# 3064      1997.0         Hector Elizondo   Lauren Holly      Jeffrey DeMunn
# 3065      2009.0         Peter Gallagher  Terry Walters          Amy Irving
# 3066      1996.0  Philip Seymour Hoffman      Alan Ruck          Jami Gertz
# 3067      2011.0         Jake Gyllenhaal      Cas Anvar      Russell Peters
#
# [2496 rows x 14 columns]

# %%
combined__.shape
# Out:
# (4730, 24)

# %%
test = pd.read_csv('../data/processed/less_than_3.csv')

# %%
test
# Out:
#       wikipedia_movie_id freebase_movie_id_x movie_release_date_x  \
# 0               37322106          /m/0hzp_vq           2012-11-13
# 1               36354224          /m/09rz62m           1953-06-19
# 2               36353890          /m/09rr39n           1953-01-14
# 3               36353520          /m/0fprltf           1953-01-31
# 4               36353137          /m/0k3m48j                 2013
# ...                  ...                 ...                  ...
# 2380               42159            /m/0bl5c                 1946
# 2381               41881            /m/0bj25                 1950
# 2382               31908            /m/07vcx           1991-12-25
# 2383                8481            /m/02c6d           1980-06-23
# 2384                4227            /m/01c9d           1975-12-18
#
#          actor1_name      actor2_name  actor3_name         character1_name  \
# 0      Shahrukh Khan              NaN          NaN             Major Samar
# 1       Anita Ekberg      Fess Parker          NaN          Dancehall Girl
# 2       Julie Newmar              NaN          NaN        Specialty Dancer
# 3     Randolph Scott              NaN          NaN  Major Ransome Callicut
# 4      Lindsay Lohan              NaN          NaN                    Tara
# ...              ...              ...          ...                     ...
# 2380   Fredric March        Myrna Loy          NaN           Al Stephenson
# 2381  Marilyn Monroe      Anne Baxter  Bette Davis            Miss Caswell
# 2382       Sam Neill     William Hurt          NaN      Eugene Fitzpatrick
# 2383   Michael Caine  Angie Dickinson          NaN   Doctor Robert Elliott
# 2384     Ryan O'Neal              NaN          NaN            Barry Lyndon
#
#        character2_name character3_name  movie_box_office_revenue
# 0                  NaN             NaN                 3047539.0
# 1            Long John             NaN                 1000000.0
# 2                  NaN             NaN                 1250000.0
# 3                  NaN             NaN                 2000000.0
# 4                  NaN             NaN                   49494.0
# ...                ...             ...                       ...
# 2380  Milly Stephenson             NaN                23650000.0
# 2381    Eve Harrington  Margo Channing                 2900000.0
# 2382        Sam Farber             NaN                  752856.0
# 2383       Kate Miller             NaN                31899000.0
# 2384               NaN             NaN                20000000.0
#
# [2385 rows x 10 columns]

# %%
import cpi
def adjust_for_inflation(df, year):

    def get_year(date):
        if pd.isna(date):  # Check if the date is NaN
            return None
        if isinstance(date, (int, float)):  # If it's already a year
            return int(date)
        elif isinstance(date, str):  # If it's a string, try to parse it as a date
            try:
                return pd.to_datetime(date).year
            except ValueError:
                return None  # Return None if date can't be parsed
        elif hasattr(date, 'year'):  # If it's a datetime object
            return date.year
        return None

    if 'movie_release_date_x' in df.columns:
        df.rename(columns={'movie_release_date_x': 'movie_release_date'}, inplace=True)

    df['years_only'] = df.apply(
        lambda row: get_year(row['movie_release_date']),
        axis=1
    )

    df['adjusted_revenue'] = df.apply(
        lambda row: cpi.inflate(row['movie_box_office_revenue'], int(row['years_only']), to=year) 
        if pd.notna(row['movie_box_office_revenue']) and pd.notna(row['years_only']) else None,
        axis=1
    )
    return df

# %%
def get_year(date):
        if pd.isna(date):  # Check if the date is NaN
            return None
        if isinstance(date, (int, float)):  # If it's already a year
            return int(date)
        elif isinstance(date, str):  # If it's a string, try to parse it as a date
            try:
                return pd.to_datetime(date).year
            except ValueError:
                return None  # Return None if date can't be parsed
        elif hasattr(date, 'year'):  # If it's a datetime object
            return date.year
        return None
test['years_only'] = test.apply(
        lambda row: get_year(row['movie_release_date']),
        axis=1
    )

# %%
test
# Out:
#       wikipedia_movie_id freebase_movie_id_x movie_release_date  \
# 0               37322106          /m/0hzp_vq         2012-11-13
# 1               36354224          /m/09rz62m         1953-06-19
# 2               36353890          /m/09rr39n         1953-01-14
# 3               36353520          /m/0fprltf         1953-01-31
# 4               36353137          /m/0k3m48j               2013
# ...                  ...                 ...                ...
# 2380               42159            /m/0bl5c               1946
# 2381               41881            /m/0bj25               1950
# 2382               31908            /m/07vcx         1991-12-25
# 2383                8481            /m/02c6d         1980-06-23
# 2384                4227            /m/01c9d         1975-12-18
#
#          actor1_name      actor2_name  actor3_name         character1_name  \
# 0      Shahrukh Khan              NaN          NaN             Major Samar
# 1       Anita Ekberg      Fess Parker          NaN          Dancehall Girl
# 2       Julie Newmar              NaN          NaN        Specialty Dancer
# 3     Randolph Scott              NaN          NaN  Major Ransome Callicut
# 4      Lindsay Lohan              NaN          NaN                    Tara
# ...              ...              ...          ...                     ...
# 2380   Fredric March        Myrna Loy          NaN           Al Stephenson
# 2381  Marilyn Monroe      Anne Baxter  Bette Davis            Miss Caswell
# 2382       Sam Neill     William Hurt          NaN      Eugene Fitzpatrick
# 2383   Michael Caine  Angie Dickinson          NaN   Doctor Robert Elliott
# 2384     Ryan O'Neal              NaN          NaN            Barry Lyndon
#
#        character2_name character3_name  movie_box_office_revenue  years_only
# 0                  NaN             NaN                 3047539.0      2012.0
# 1            Long John             NaN                 1000000.0      1953.0
# 2                  NaN             NaN                 1250000.0      1953.0
# 3                  NaN             NaN                 2000000.0      1953.0
# 4                  NaN             NaN                   49494.0      2013.0
# ...                ...             ...                       ...         ...
# 2380  Milly Stephenson             NaN                23650000.0      1946.0
# 2381    Eve Harrington  Margo Channing                 2900000.0      1950.0
# 2382        Sam Farber             NaN                  752856.0      1991.0
# 2383       Kate Miller             NaN                31899000.0      1980.0
# 2384               NaN             NaN                20000000.0      1975.0
#
# [2385 rows x 11 columns]

# %%
oue = adjust_for_inflation(test, year=2015)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 oue = adjust_for_inflation(test, year=2015)
#
# Cell In[101], line 26, in adjust_for_inflation(df, year)
#      19     df.rename(columns={'movie_release_date_x': 'movie_release_date'}, inplace=True)
#      21 df['years_only'] = df.apply(
#      22     lambda row: get_year(row['movie_release_date']),
#      23     axis=1
#      24 )
# ---> 26 df['adjusted_revenue'] = df.apply(
#      27     lambda row: cpi.inflate(row['movie_box_office_revenue'], int(row['years_only']), to=year)
#      28     if pd.notna(row['movie_box_office_revenue']) and pd.notna(row['years_only']) else None,
#      29     axis=1
#      30 )
#      31 return df
#
# File c:\Users\arthu\anaconda3\envs\ada\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\arthu\anaconda3\envs\ada\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\arthu\anaconda3\envs\ada\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\arthu\anaconda3\envs\ada\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[101], line 27, in adjust_for_inflation.<locals>.<lambda>(row)
#      19     df.rename(columns={'movie_release_date_x': 'movie_release_date'}, inplace=True)
#      21 df['years_only'] = df.apply(
#      22     lambda row: get_year(row['movie_release_date']),
#      23     axis=1
#      24 )
#      26 df['adjusted_revenue'] = df.apply(
# ---> 27     lambda row: cpi.inflate(row['movie_box_office_revenue'], int(row['years_only']), to=year)
#      28     if pd.notna(row['movie_box_office_revenue']) and pd.notna(row['years_only']) else None,
#      29     axis=1
#      30 )
#      31 return df
#
# File c:\Users\arthu\anaconda3\envs\ada\Lib\site-packages\cpi\__init__.py:163, in inflate(value, year_or_month, to, survey, seasonally_adjusted, periodicity, area, items, series_id)
#     154 kwargs = {
#     155     "survey": survey,
#     156     "seasonally_adjusted": seasonally_adjusted,
#    (...)
#     160     "series_id": series_id,
#     161 }
#     162 source_index = get(year_or_month, **kwargs)
# --> 163 target_index = get(to, **kwargs)
#     164 return (value * target_index) / float(source_index)
#
# File c:\Users\arthu\anaconda3\envs\ada\Lib\site-packages\cpi\__init__.py:76, in get(year_or_month, survey, seasonally_adjusted, periodicity, area, items, series_id)
#      73     series_obj = series.get_by_id(series_id)
#      74 else:
#      75     # Otherwise, we build the series id using the more humanized options
# ---> 76     series_obj = series.get(survey, seasonally_adjusted, periodicity, area, items)
#      78 # Prep the lookup value depending on the input type.
#      79 if isinstance(year_or_month, numbers.Integral):
#
# File c:\Users\arthu\anaconda3\envs\ada\Lib\site-packages\cpi\models.py:437, in SeriesList.get(self, survey, seasonally_adjusted, periodicity, area, items)
#     428 series_id = "{}{}{}{}{}".format(
#     429     survey_code,
#     430     seasonality_code,
#    (...)
#     433     Item.get_by_name(items).code,
#     434 )
#     436 # Pull the series
# --> 437 return Series.get_by_id(series_id)
#
# File c:\Users\arthu\anaconda3\envs\ada\Lib\site-packages\cpi\models.py:324, in Series.get_by_id(cls, value)
#     321 d["items"] = Item.get_by_id(d["items"])
#     323 # Get the indexes
# --> 324 dict_list = query("SELECT * FROM 'indexes' WHERE series=?", (value,))
#     326 # Cache the periods to reduce queries
#     327 period_cache = {p.id: p for p in Period.all()}
#
# File c:\Users\arthu\anaconda3\envs\ada\Lib\site-packages\cpi\models.py:46, in query(sql, params)
#      44     query = cursor.execute(sql, params)
#      45 columns = [d[0] for d in query.description]
# ---> 46 result_list = [dict(zip(columns, r)) for r in query.fetchall()]
#      48 # Close
#      49 conn.close()
#
# KeyboardInterrupt:

# %%
oue
# Out:
#       wikipedia_movie_id freebase_movie_id_x movie_release_date  \
# 0               37322106          /m/0hzp_vq         2012-11-13
# 1               36354224          /m/09rz62m         1953-06-19
# 2               36353890          /m/09rr39n         1953-01-14
# 3               36353520          /m/0fprltf         1953-01-31
# 4               36353137          /m/0k3m48j               2013
# ...                  ...                 ...                ...
# 2380               42159            /m/0bl5c               1946
# 2381               41881            /m/0bj25               1950
# 2382               31908            /m/07vcx         1991-12-25
# 2383                8481            /m/02c6d         1980-06-23
# 2384                4227            /m/01c9d         1975-12-18
#
#          actor1_name      actor2_name  actor3_name         character1_name  \
# 0      Shahrukh Khan              NaN          NaN             Major Samar
# 1       Anita Ekberg      Fess Parker          NaN          Dancehall Girl
# 2       Julie Newmar              NaN          NaN        Specialty Dancer
# 3     Randolph Scott              NaN          NaN  Major Ransome Callicut
# 4      Lindsay Lohan              NaN          NaN                    Tara
# ...              ...              ...          ...                     ...
# 2380   Fredric March        Myrna Loy          NaN           Al Stephenson
# 2381  Marilyn Monroe      Anne Baxter  Bette Davis            Miss Caswell
# 2382       Sam Neill     William Hurt          NaN      Eugene Fitzpatrick
# 2383   Michael Caine  Angie Dickinson          NaN   Doctor Robert Elliott
# 2384     Ryan O'Neal              NaN          NaN            Barry Lyndon
#
#        character2_name character3_name  movie_box_office_revenue  years_only  \
# 0                  NaN             NaN                 3047539.0      2012.0
# 1            Long John             NaN                 1000000.0      1953.0
# 2                  NaN             NaN                 1250000.0      1953.0
# 3                  NaN             NaN                 2000000.0      1953.0
# 4                  NaN             NaN                   49494.0      2013.0
# ...                ...             ...                       ...         ...
# 2380  Milly Stephenson             NaN                23650000.0      1946.0
# 2381    Eve Harrington  Margo Channing                 2900000.0      1950.0
# 2382        Sam Farber             NaN                  752856.0      1991.0
# 2383       Kate Miller             NaN                31899000.0      1980.0
# 2384               NaN             NaN                20000000.0      1975.0
#
#      adjusted_revenue
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
# ...               ...
# 2380             None
# 2381             None
# 2382             None
# 2383             None
# 2384             None
#
# [2385 rows x 12 columns]

# %%
tests = pd.read_csv('../data/processed/imdbtest.csv')
tests
# Out:
#       wikipedia_movie_id freebase_movie_id      movie_name  \
# 0                 975900         /m/03vyhn  Ghosts of Mars
# 1                 171005         /m/016ywb         Henry V
# 2                  77856          /m/0kcn7    Mary Poppins
# 3                 156558         /m/014k4y        Baby Boy
# 4                1305819         /m/04rjwf        C.H.U.D.
# ...                  ...               ...             ...
# 2491            10149834        /m/02q3fdr           Ponyo
# 2492             2472440         /m/07gf00      Turbulence
# 2493            22427855        /m/05zkcsk            Adam
# 2494              303933         /m/01s7w3         Twister
# 2495            25920477        /m/0b6lqyd     Source Code
#
#       movie_release_date  movie_box_office_revenue  movie_runtime  \
# 0                   2001                14010832.0           98.0
# 1                   1989                10161099.0          137.0
# 2                   1964               102272727.0          139.0
# 3                   2001                29381649.0          123.0
# 4                   1984                 4650000.0           96.0
# ...                  ...                       ...            ...
# 2491                2008               202614288.0          101.0
# 2492                1997                11538235.0          101.0
# 2493                2009                 2549605.0           99.0
# 2494                1996               494471524.0          113.0
# 2495                2011               147332697.0           93.0
#
#             movie_languages                         movie_countries  \
# 0      ['English Language']            ['United States of America']
# 1      ['English Language']                      ['United Kingdom']
# 2      ['English Language']            ['United States of America']
# 3      ['English Language']            ['United States of America']
# 4      ['English Language']            ['United States of America']
# ...                     ...                                     ...
# 2491  ['Japanese Language']                               ['Japan']
# 2492   ['English Language']            ['United States of America']
# 2493   ['English Language']            ['United States of America']
# 2494   ['English Language']            ['United States of America']
# 2495   ['English Language']  ['France', 'United States of America']
#
#                                            movie_genres     movie_title  \
# 0     ['Thriller', 'Science Fiction', 'Horror', 'Adv...  Ghosts of Mars
# 1     ['Costume drama', 'War film', 'Epic', 'Period ...         Henry V
# 2     ["Children's/Family", 'Musical', 'Fantasy', 'C...    Mary Poppins
# 3           ['Crime Fiction', 'Drama', 'Coming of age']        Baby Boy
# 4     ['Monster movie', 'Natural horror films', 'Sci...        C.H.U.D.
# ...                                                 ...             ...
# 2491  ['Japanese Movies', 'Adventure', 'World cinema...           Ponyo
# 2492  ['Thriller', 'Disaster', 'Action', 'Action/Adv...      Turbulence
# 2493  ['Indie', 'Comedy-drama', 'Drama', 'Comedy', '...            Adam
# 2494                   ['Action/Adventure', 'Disaster']         Twister
# 2495  ['Thriller', 'Science Fiction', 'Action/Advent...     Source Code
#
#       title_year            actor_1_name   actor_2_name        actor_3_name
# 0         2001.0           Jason Statham    Clea DuVall  Natasha Henstridge
# 1         1989.0           Brian Blessed   Derek Jacobi          Danny Webb
# 2         1964.0                 Ed Wynn   Glynis Johns     Elsa Lanchester
# 3         2001.0                Mo'Nique     Snoop Dogg      Angell Conwell
# 4         1984.0            Daniel Stern     John Heard        Sam McMurray
# ...          ...                     ...            ...                 ...
# 2491      2008.0            Rumi Hiiragi     Yûki Amami          Yuria Nara
# 2492      1997.0         Hector Elizondo   Lauren Holly      Jeffrey DeMunn
# 2493      2009.0         Peter Gallagher  Terry Walters          Amy Irving
# 2494      1996.0  Philip Seymour Hoffman      Alan Ruck          Jami Gertz
# 2495      2011.0         Jake Gyllenhaal      Cas Anvar      Russell Peters
#
# [2496 rows x 14 columns]

# %%
yo = pd.read_csv('../data/processed/movies_x_principal_characters.csv')

# %%
yo
# Out:
#       wikipedia_movie_id freebase_movie_id_x movie_release_date  \
# 0               37322106          /m/0hzp_vq         2012-11-13
# 1               36354224          /m/09rz62m         1953-06-19
# 2               36353890          /m/09rr39n         1953-01-14
# 3               36353520          /m/0fprltf         1953-01-31
# 4               36353137          /m/0k3m48j               2013
# ...                  ...                 ...                ...
# 2380               42159            /m/0bl5c               1946
# 2381               41881            /m/0bj25               1950
# 2382               31908            /m/07vcx         1991-12-25
# 2383                8481            /m/02c6d         1980-06-23
# 2384                4227            /m/01c9d         1975-12-18
#
#          actor1_name      actor2_name  actor3_name         character1_name  \
# 0      Shahrukh Khan              NaN          NaN             Major Samar
# 1       Anita Ekberg      Fess Parker          NaN          Dancehall Girl
# 2       Julie Newmar              NaN          NaN        Specialty Dancer
# 3     Randolph Scott              NaN          NaN  Major Ransome Callicut
# 4      Lindsay Lohan              NaN          NaN                    Tara
# ...              ...              ...          ...                     ...
# 2380   Fredric March        Myrna Loy          NaN           Al Stephenson
# 2381  Marilyn Monroe      Anne Baxter  Bette Davis            Miss Caswell
# 2382       Sam Neill     William Hurt          NaN      Eugene Fitzpatrick
# 2383   Michael Caine  Angie Dickinson          NaN   Doctor Robert Elliott
# 2384     Ryan O'Neal              NaN          NaN            Barry Lyndon
#
#        character2_name character3_name  movie_box_office_revenue  years_only  \
# 0                  NaN             NaN                 3047539.0      2012.0
# 1            Long John             NaN                 1000000.0      1953.0
# 2                  NaN             NaN                 1250000.0      1953.0
# 3                  NaN             NaN                 2000000.0      1953.0
# 4                  NaN             NaN                   49494.0      2013.0
# ...                ...             ...                       ...         ...
# 2380  Milly Stephenson             NaN                23650000.0      1946.0
# 2381    Eve Harrington  Margo Channing                 2900000.0      1950.0
# 2382        Sam Farber             NaN                  752856.0      1991.0
# 2383       Kate Miller             NaN                31899000.0      1980.0
# 2384               NaN             NaN                20000000.0      1975.0
#
#       adjusted_revenue
# 0         3.146069e+06
# 1         8.877041e+06
# 2         1.109630e+07
# 3         1.775408e+07
# 4         5.035659e+04
# ...                ...
# 2380      2.874591e+08
# 2381      2.852072e+07
# 2382      1.310130e+06
# 2383      9.175492e+07
# 2384      8.811041e+07
#
# [2385 rows x 12 columns]

# %%
import pandas as pd

# %%
yoz = pd.read_csv('../data/processed/movies_trope_summary_main_actors_IMDB.csv')
yoz
# Out:
#       wikipedia_movie_id freebase_movie_id  \
# 0                 975900         /m/03vyhn
# 1                 171005         /m/016ywb
# 2                  77856          /m/0kcn7
# 3                 156558         /m/014k4y
# 4                3550323         /m/09kzfd
# ...                  ...               ...
# 2823             2472440         /m/07gf00
# 2824            22427855        /m/05zkcsk
# 2825              303933         /m/01s7w3
# 2826            25920477        /m/0b6lqyd
# 2827             7761830         /m/0kvgqb
#
#                                    movie_name  movie_release_date  \
# 0                              Ghosts of Mars                2001
# 1                                     Henry V                1989
# 2                                Mary Poppins                1964
# 3                                    Baby Boy                2001
# 4     Things to Do in Denver When You're Dead                1995
# ...                                       ...                 ...
# 2823                               Turbulence                1997
# 2824                                     Adam                2009
# 2825                                  Twister                1996
# 2826                              Source Code                2011
# 2827                          Spaced Invaders                1990
#
#       movie_box_office_revenue  movie_runtime       movie_languages  \
# 0                   14010832.0           98.0  ['English Language']
# 1                   10161099.0          137.0  ['English Language']
# 2                  102272727.0          139.0  ['English Language']
# 3                   29381649.0          123.0  ['English Language']
# 4                     529677.0          115.0  ['English Language']
# ...                        ...            ...                   ...
# 2823                11538235.0          101.0  ['English Language']
# 2824                 2549605.0           99.0  ['English Language']
# 2825               494471524.0          113.0  ['English Language']
# 2826               147332697.0           93.0  ['English Language']
# 2827                15369573.0          100.0  ['English Language']
#
#                              movie_countries  \
# 0               ['United States of America']
# 1                         ['United Kingdom']
# 2               ['United States of America']
# 3               ['United States of America']
# 4               ['United States of America']
# ...                                      ...
# 2823            ['United States of America']
# 2824            ['United States of America']
# 2825            ['United States of America']
# 2826  ['France', 'United States of America']
# 2827            ['United States of America']
#
#                                            movie_genres  \
# 0     ['Thriller', 'Science Fiction', 'Horror', 'Adv...
# 1     ['Costume drama', 'War film', 'Epic', 'Period ...
# 2     ["Children's/Family", 'Musical', 'Fantasy', 'C...
# 3           ['Crime Fiction', 'Drama', 'Coming of age']
# 4     ['Thriller', 'Crime Fiction', 'Crime Comedy', ...
# ...                                                 ...
# 2823  ['Thriller', 'Disaster', 'Action', 'Action/Adv...
# 2824  ['Indie', 'Comedy-drama', 'Drama', 'Comedy', '...
# 2825                   ['Action/Adventure', 'Disaster']
# 2826  ['Thriller', 'Science Fiction', 'Action/Advent...
# 2827  ['Alien Film', 'Science Fiction', 'Family Film...
#
#                                   movie_title  title_year  \
# 0                              Ghosts of Mars      2001.0
# 1                                     Henry V      1989.0
# 2                                Mary Poppins      1964.0
# 3                                    Baby Boy      2001.0
# 4     Things to Do in Denver When You're Dead      1995.0
# ...                                       ...         ...
# 2823                               Turbulence      1997.0
# 2824                                     Adam      2009.0
# 2825                                  Twister      1996.0
# 2826                              Source Code      2011.0
# 2827                          Spaced Invaders      1990.0
#
#                 actor_1_name   actor_2_name        actor_3_name  years_only  \
# 0              Jason Statham    Clea DuVall  Natasha Henstridge        2001
# 1              Brian Blessed   Derek Jacobi          Danny Webb        1989
# 2                    Ed Wynn   Glynis Johns     Elsa Lanchester        1964
# 3                   Mo'Nique     Snoop Dogg      Angell Conwell        2001
# 4              Steve Buscemi     Bill Cobbs      Treat Williams        1995
# ...                      ...            ...                 ...         ...
# 2823         Hector Elizondo   Lauren Holly      Jeffrey DeMunn        1997
# 2824         Peter Gallagher  Terry Walters          Amy Irving        2009
# 2825  Philip Seymour Hoffman      Alan Ruck          Jami Gertz        1996
# 2826         Jake Gyllenhaal      Cas Anvar      Russell Peters        2011
# 2827         Ariana Richards     Royal Dano  Tonya Lee Williams        1990
#
#       adjusted_revenue
# 0         1.875102e+07
# 1         1.942220e+07
# 2         7.819476e+08
# 3         3.932214e+07
# 4         8.237694e+05
# ...                ...
# 2823      1.703899e+07
# 2824      2.816762e+06
# 2825      7.469608e+08
# 2826      1.552437e+08
# 2827      2.787184e+07
#
# [2828 rows x 16 columns]
